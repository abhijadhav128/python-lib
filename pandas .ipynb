# %%
#pandas series in 1D

# %%
import pandas as pd

# %%
l1=[1,2,3,4,5]
s=pd.Series(l1)

# %%
#change index
s=pd.Series(l1,index=['a','b','c','d','e'])
s
# Out:
# a    1
# b    2
# c    3
# d    4
# e    5
# dtype: int64

# %%
#extracting from series 
s[1:]
# Out:
# b    2
# c    3
# d    4
# e    5
# dtype: int64

# %%
#DATA FRAME IN 2D 
#Syntax : pd.DataFrame

# %%
import pandas as pd
s=pd.read_csv('example.csv')
s
# Out:
#        id first_name      last_name                           email  gender  \
# 0       1     Joseph      Zaniolini  jzaniolini0@simplemachines.org    Male
# 1       2     Freida  Drillingcourt       fdrillingcourt1@umich.edu  Female
# 2       3      Nanni         Herity        nherity2@statcounter.com  Female
# 3       4     Orazio       Frayling        ofrayling3@economist.com    Male
# 4       5   Julianne       Murrison         jmurrison4@cbslocal.com  Female
# ..    ...        ...            ...                             ...     ...
# 995   996   Parrnell           Jeff             pjeffrn@4shared.com    Male
# 996   997        Pat       Warstall         pwarstallro@dropbox.com    Male
# 997   998     Willyt     Vannuccini     wvannuccinirp@tuttocitta.it  Female
# 998   999     Gaelan     Petrashkov     gpetrashkovrq@hostgator.com    Male
# 999  1000   Stirling       Francesc     sfrancescrr@cyberchimps.com    Male
#
#          ip_address                   city
# ...

# %%
s.head()
# Out:
#    id first_name      last_name                           email  gender  \
# 0   1     Joseph      Zaniolini  jzaniolini0@simplemachines.org    Male
# 1   2     Freida  Drillingcourt       fdrillingcourt1@umich.edu  Female
# 2   3      Nanni         Herity        nherity2@statcounter.com  Female
# 3   4     Orazio       Frayling        ofrayling3@economist.com    Male
# 4   5   Julianne       Murrison         jmurrison4@cbslocal.com  Female
#
#        ip_address                   city
# 0  163.168.68.132         Pedro Leopoldo
# 1   97.212.102.79                   Buri
# 2  145.151.178.98                 Claver
# 3  25.199.143.143                 Kungur
# 4  10.186.243.144  Sainte-Luce-sur-Loire

# %%
s.tail()
# Out:
#        id first_name   last_name                        email  gender  \
# 995   996   Parrnell        Jeff          pjeffrn@4shared.com    Male
# 996   997        Pat    Warstall      pwarstallro@dropbox.com    Male
# 997   998     Willyt  Vannuccini  wvannuccinirp@tuttocitta.it  Female
# 998   999     Gaelan  Petrashkov  gpetrashkovrq@hostgator.com    Male
# 999  1000   Stirling    Francesc  sfrancescrr@cyberchimps.com    Male
#
#          ip_address            city
# 995    159.55.55.39          Dengok
# 996   169.200.7.131  Rosário do Sul
# 997  156.149.18.155      Xiaopingba
# 998  219.109.169.75       Bethlehem
# 999   108.193.9.206     Potok Złoty

# %%
s.shape
# Out:
# (1000, 7)

# %%
s.describe()
# Out:
#                 id
# count  1000.000000
# mean    500.500000
# std     288.819436
# min       1.000000
# 25%     250.750000
# 50%     500.500000
# 75%     750.250000
# max    1000.000000

# %%
#.iloc and loc it is use to extract coloum

# %%
s.iloc[0:3,0:4]
# Out:
#    id first_name      last_name                           email
# 0   1     Joseph      Zaniolini  jzaniolini0@simplemachines.org
# 1   2     Freida  Drillingcourt       fdrillingcourt1@umich.edu
# 2   3      Nanni         Herity        nherity2@statcounter.com

# %%
s.loc[0:3,("first_name",'email')]
# Out:
#   first_name                           email
# 0     Joseph  jzaniolini0@simplemachines.org
# 1     Freida       fdrillingcourt1@umich.edu
# 2      Nanni        nherity2@statcounter.com
# 3     Orazio        ofrayling3@economist.com

# %%
#Droping the row(axis=0)and columns(axis=1)

# %%
s.drop([1,2,3],axis=0)
# Out:
#        id first_name   last_name                           email  gender  \
# 0       1     Joseph   Zaniolini  jzaniolini0@simplemachines.org    Male
# 4       5   Julianne    Murrison         jmurrison4@cbslocal.com  Female
# 5       6       Lucy       Gamet         lgamet5@list-manage.com  Female
# 6       7      Dyana      Howatt             dhowatt6@amazon.com  Female
# 7       8     Kassey      Herion             kherion7@amazon.com  Female
# ..    ...        ...         ...                             ...     ...
# 995   996   Parrnell        Jeff             pjeffrn@4shared.com    Male
# 996   997        Pat    Warstall         pwarstallro@dropbox.com    Male
# 997   998     Willyt  Vannuccini     wvannuccinirp@tuttocitta.it  Female
# 998   999     Gaelan  Petrashkov     gpetrashkovrq@hostgator.com    Male
# 999  1000   Stirling    Francesc     sfrancescrr@cyberchimps.com    Male
#
#          ip_address                   city
# 0    163.168.68.132         Pedro Leopoldo
# ...

# %%
s.drop(["email"],axis=1)
# Out:
#        id first_name      last_name  gender      ip_address  \
# 0       1     Joseph      Zaniolini    Male  163.168.68.132
# 1       2     Freida  Drillingcourt  Female   97.212.102.79
# 2       3      Nanni         Herity  Female  145.151.178.98
# 3       4     Orazio       Frayling    Male  25.199.143.143
# 4       5   Julianne       Murrison  Female  10.186.243.144
# ..    ...        ...            ...     ...             ...
# 995   996   Parrnell           Jeff    Male    159.55.55.39
# 996   997        Pat       Warstall    Male   169.200.7.131
# 997   998     Willyt     Vannuccini  Female  156.149.18.155
# 998   999     Gaelan     Petrashkov    Male  219.109.169.75
# 999  1000   Stirling       Francesc    Male   108.193.9.206
#
#                       city
# 0           Pedro Leopoldo
# 1                     Buri
# 2                   Claver
# 3                   Kungur
# 4    Sainte-Luce-sur-Loire
# ..                     ...
# 995                 Dengok
# ...

# %%
def half(s):
    return s*0.5

# %%
s[['id',]].apply(half)
# Out:
#         id
# 0      0.5
# 1      1.0
# 2      1.5
# 3      2.0
# 4      2.5
# ..     ...
# 995  498.0
# 996  498.5
# 997  499.0
# 998  499.5
# 999  500.0
#
# [1000 rows x 1 columns]

# %%
#value_count and sort.value
s.head()
# Out:
#    id first_name      last_name                           email  gender  \
# 0   1     Joseph      Zaniolini  jzaniolini0@simplemachines.org    Male
# 1   2     Freida  Drillingcourt       fdrillingcourt1@umich.edu  Female
# 2   3      Nanni         Herity        nherity2@statcounter.com  Female
# 3   4     Orazio       Frayling        ofrayling3@economist.com    Male
# 4   5   Julianne       Murrison         jmurrison4@cbslocal.com  Female
#
#        ip_address                   city
# 0  163.168.68.132         Pedro Leopoldo
# 1   97.212.102.79                   Buri
# 2  145.151.178.98                 Claver
# 3  25.199.143.143                 Kungur
# 4  10.186.243.144  Sainte-Luce-sur-Loire

# %%
s['city'].value_count()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_21968/2214038028.py in <module>
# ----> 1 s['city'].value_count()
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5485         ):
#    5486             return self[name]
# -> 5487         return object.__getattribute__(self, name)
#    5488
#    5489     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'Series' object has no attribute 'value_count'

# %%
s.sort_values(by='city')
# Out:
#       id first_name   last_name                        email  gender  \
# 293  294    Godfrey    Cattrell        gcattrell85@state.gov    Male
# 667  668     Penrod       Tures      pturesij@soundcloud.com    Male
# 888  889    Webster  Leppington  wleppingtonoo@people.com.cn    Male
# 341  342      Gayla      Hebbes            ghebbes9h@gnu.org  Female
# 913  914    Delinda      Kiebes           dkiebespd@blog.com  Female
# ..   ...        ...         ...                          ...     ...
# 585  586    Elspeth  Kleinzweig      ekleinzweigg9@blogs.com  Female
# 143  144     Ermina       Carff         ecarff3z@tinyurl.com  Female
# 452  453    Lavinia  Englefield  lenglefieldck@google.com.au  Female
# 258  259       Noel    Selliman  nselliman76@istockphoto.com    Male
# 990  991        Bat  Tomczynski     btomczynskiri@toplist.cz    Male
#
#           ip_address              city
# 293      13.184.11.7  Abdurahmoni Jomí
# 667    164.134.78.50         Abejorral
# ...

# %%
from matplotlib import pyplot as plt
import seaborn as sns 
import pandas as pd

# %%
diamond = pd.read_csv('iris.csv')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_3164/677041490.py in <module>
# ----> 1 diamond = pd.read_csv('iris.csv')
#
# ~\anaconda3\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ...
